# %%
from pre_processing_functions import *

# %%
feature_selection('customer_info.csv', 'correlation',  threshold=0.01,correlation_threshold=0.80)
# Out:
# /Users/matildepanarra/Documents/ml2.project/pre_processing_functions.py:166: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr().abs()
# customer_id                                 True
# customer_name                               True
# customer_gender                             True
# kids_home                                   True
# teens_home                                  True
# number_complaints                           True
# distinct_stores_visited                     True
# lifetime_spend_groceries                    True
# lifetime_spend_electronics                  True
# typical_hour                                True
# lifetime_spend_vegetables                   True
# lifetime_spend_nonalcohol_drinks            True
# lifetime_spend_alcohol_drinks               True
# lifetime_spend_meat                         True
# lifetime_spend_fish                         True
# lifetime_spend_hygiene                      True
# lifetime_spend_videogames                   True
# lifetime_spend_petfood                      True
# lifetime_total_distinct_products            True
# percentage_of_products_bought_promotion     True
# year_first_transaction                      True
# loyalty_card_number                         True
# latitude                                    True
# longitude                                   True
# customer_age                                True
# years_active                               False
# customer_educlevel                          True
# Name: Keep (Correlation), dtype: bool

# %%
df= preprocess('customer_info.csv')

# %%
df.corr(numeric_only=True).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_dc9cf_row0_col0, #T_dc9cf_row1_col1, #T_dc9cf_row2_col2, #T_dc9cf_row3_col3, #T_dc9cf_row4_col4, #T_dc9cf_row5_col5, #T_dc9cf_row6_col6, #T_dc9cf_row7_col7, #T_dc9cf_row8_col8, #T_dc9cf_row9_col9, #T_dc9cf_row10_col10, #T_dc9cf_row11_col11, #T_dc9cf_row12_col12, #T_dc9cf_row13_col13, #T_dc9cf_row14_col14, #T_dc9cf_row15_col15, #T_dc9cf_row16_col16, #T_dc9cf_row17_col17, #T_dc9cf_row18_col18, #T_dc9cf_row19_col19, #T_dc9cf_row20_col20, #T_dc9cf_row21_col21, #T_dc9cf_row22_col22, #T_dc9cf_row23_col23, #T_dc9cf_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col1, #T_dc9cf_row4_col1, #T_dc9cf_row5_col1, #T_dc9cf_row11_col1, #T_dc9cf_row13_col1, #T_dc9cf_row16_col1, #T_dc9cf_row17_col1, #T_dc9cf_row18_col1, #T_dc9cf_row18_col6, #T_dc9cf_row18_col21, #T_dc9cf_row22_col1, #T_dc9cf_row24_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col2, #T_dc9cf_row1_col2, #T_dc9cf_row1_col8, #T_dc9cf_row7_col2, #T_dc9cf_row9_col8, #T_dc9cf_row10_col16, #T_dc9cf_row17_col9, #T_dc9cf_row21_col13 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col3, #T_dc9cf_row1_col3, #T_dc9cf_row3_col9, #T_dc9cf_row5_col8, #T_dc9cf_row7_col9, #T_dc9cf_row22_col17 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col4, #T_dc9cf_row0_col14, #T_dc9cf_row1_col6, #T_dc9cf_row1_col14 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col5, #T_dc9cf_row9_col14, #T_dc9cf_row19_col7, #T_dc9cf_row21_col5, #T_dc9cf_row23_col14 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_dc9cf_row0_col6, #T_dc9cf_row1_col4, #T_dc9cf_row5_col12, #T_dc9cf_row6_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col7, #T_dc9cf_row0_col10, #T_dc9cf_row6_col3, #T_dc9cf_row8_col5, #T_dc9cf_row14_col7, #T_dc9cf_row16_col9, #T_dc9cf_row17_col16, #T_dc9cf_row20_col13, #T_dc9cf_row21_col12, #T_dc9cf_row22_col6, #T_dc9cf_row22_col12 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_dc9cf_row0_col8, #T_dc9cf_row20_col8 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col9, #T_dc9cf_row8_col7, #T_dc9cf_row8_col23, #T_dc9cf_row11_col9, #T_dc9cf_row16_col5, #T_dc9cf_row18_col4, #T_dc9cf_row20_col9, #T_dc9cf_row23_col17 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_dc9cf_row0_col11, #T_dc9cf_row1_col9, #T_dc9cf_row8_col9, #T_dc9cf_row15_col17, #T_dc9cf_row20_col10, #T_dc9cf_row21_col23 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_dc9cf_row0_col12, #T_dc9cf_row3_col7, #T_dc9cf_row4_col23, #T_dc9cf_row14_col16, #T_dc9cf_row20_col15, #T_dc9cf_row21_col17 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col13, #T_dc9cf_row1_col17, #T_dc9cf_row13_col9, #T_dc9cf_row22_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col15, #T_dc9cf_row6_col8, #T_dc9cf_row9_col10, #T_dc9cf_row11_col23, #T_dc9cf_row21_col7, #T_dc9cf_row23_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_dc9cf_row0_col16, #T_dc9cf_row1_col22, #T_dc9cf_row7_col4, #T_dc9cf_row11_col5, #T_dc9cf_row12_col9, #T_dc9cf_row17_col8, #T_dc9cf_row22_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col17, #T_dc9cf_row2_col18, #T_dc9cf_row7_col14, #T_dc9cf_row18_col3, #T_dc9cf_row18_col23 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col18, #T_dc9cf_row1_col18, #T_dc9cf_row9_col5, #T_dc9cf_row16_col14, #T_dc9cf_row21_col15 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_dc9cf_row0_col19, #T_dc9cf_row1_col19, #T_dc9cf_row2_col10 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_dc9cf_row0_col20, #T_dc9cf_row2_col1, #T_dc9cf_row2_col8, #T_dc9cf_row3_col1, #T_dc9cf_row4_col6, #T_dc9cf_row4_col22, #T_dc9cf_row5_col7, #T_dc9cf_row5_col15, #T_dc9cf_row6_col4, #T_dc9cf_row8_col1, #T_dc9cf_row8_col2, #T_dc9cf_row8_col3, #T_dc9cf_row9_col1, #T_dc9cf_row9_col4, #T_dc9cf_row9_col12, #T_dc9cf_row10_col1, #T_dc9cf_row11_col18, #T_dc9cf_row14_col1, #T_dc9cf_row15_col5, #T_dc9cf_row18_col9, #T_dc9cf_row18_col10, #T_dc9cf_row18_col11, #T_dc9cf_row18_col13, #T_dc9cf_row19_col1, #T_dc9cf_row19_col14, #T_dc9cf_row19_col16, #T_dc9cf_row19_col17, #T_dc9cf_row19_col21, #T_dc9cf_row19_col23, #T_dc9cf_row19_col24, #T_dc9cf_row20_col0, #T_dc9cf_row20_col1, #T_dc9cf_row24_col19 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col21, #T_dc9cf_row3_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col22, #T_dc9cf_row15_col3, #T_dc9cf_row15_col14 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_dc9cf_row0_col23, #T_dc9cf_row5_col10, #T_dc9cf_row11_col16, #T_dc9cf_row18_col8, #T_dc9cf_row22_col23, #T_dc9cf_row23_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_dc9cf_row0_col24, #T_dc9cf_row1_col24, #T_dc9cf_row24_col23 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_dc9cf_row1_col0, #T_dc9cf_row8_col0, #T_dc9cf_row8_col20, #T_dc9cf_row9_col0, #T_dc9cf_row16_col0, #T_dc9cf_row18_col0, #T_dc9cf_row20_col5, #T_dc9cf_row22_col0, #T_dc9cf_row24_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_dc9cf_row1_col5, #T_dc9cf_row3_col18, #T_dc9cf_row6_col9, #T_dc9cf_row7_col8, #T_dc9cf_row10_col5, #T_dc9cf_row16_col2, #T_dc9cf_row21_col18 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_dc9cf_row1_col7, #T_dc9cf_row1_col10, #T_dc9cf_row4_col3, #T_dc9cf_row5_col17, #T_dc9cf_row12_col5, #T_dc9cf_row16_col18, #T_dc9cf_row22_col2, #T_dc9cf_row22_col3, #T_dc9cf_row23_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_dc9cf_row1_col11, #T_dc9cf_row5_col2, #T_dc9cf_row9_col11, #T_dc9cf_row19_col8, #T_dc9cf_row20_col14 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_dc9cf_row1_col12, #T_dc9cf_row3_col4, #T_dc9cf_row3_col6, #T_dc9cf_row8_col11, #T_dc9cf_row21_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_dc9cf_row1_col13, #T_dc9cf_row16_col8, #T_dc9cf_row19_col4, #T_dc9cf_row21_col14, #T_dc9cf_row22_col15 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_dc9cf_row1_col15, #T_dc9cf_row9_col2, #T_dc9cf_row22_col18, #T_dc9cf_row23_col13, #T_dc9cf_row24_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_dc9cf_row1_col16, #T_dc9cf_row23_col22 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_dc9cf_row1_col20, #T_dc9cf_row3_col0, #T_dc9cf_row5_col0, #T_dc9cf_row6_col0, #T_dc9cf_row7_col0, #T_dc9cf_row7_col17, #T_dc9cf_row9_col20, #T_dc9cf_row17_col0, #T_dc9cf_row21_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_dc9cf_row1_col21, #T_dc9cf_row2_col21, #T_dc9cf_row9_col16, #T_dc9cf_row17_col21, #T_dc9cf_row18_col16 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_dc9cf_row1_col23, #T_dc9cf_row4_col5, #T_dc9cf_row20_col11, #T_dc9cf_row21_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_dc9cf_row2_col0, #T_dc9cf_row10_col0, #T_dc9cf_row11_col0, #T_dc9cf_row13_col0, #T_dc9cf_row14_col0, #T_dc9cf_row14_col13, #T_dc9cf_row15_col0, #T_dc9cf_row15_col6, #T_dc9cf_row19_col0, #T_dc9cf_row23_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_dc9cf_row2_col3 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_dc9cf_row2_col4, #T_dc9cf_row5_col23, #T_dc9cf_row16_col23 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_dc9cf_row2_col5, #T_dc9cf_row2_col9, #T_dc9cf_row7_col23, #T_dc9cf_row17_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_dc9cf_row2_col6, #T_dc9cf_row7_col18 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_dc9cf_row2_col7, #T_dc9cf_row2_col23, #T_dc9cf_row21_col2, #T_dc9cf_row22_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_dc9cf_row2_col11, #T_dc9cf_row10_col2, #T_dc9cf_row10_col7, #T_dc9cf_row10_col14 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_dc9cf_row2_col12, #T_dc9cf_row4_col0, #T_dc9cf_row5_col18, #T_dc9cf_row12_col19, #T_dc9cf_row14_col11 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_dc9cf_row2_col13, #T_dc9cf_row9_col23, #T_dc9cf_row11_col14, #T_dc9cf_row16_col3, #T_dc9cf_row16_col17, #T_dc9cf_row23_col19, #T_dc9cf_row24_col2 {
#   background-color: #a9
